# %%
M=np.array([[5,6,7],[2,4,3],[8,9.10],[0,2,3]])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 M=np.array([[5,6,7],[2,4,3],[8,9.10],[0,2,3]])
#
# ValueError: setting an array element with a sequence. The requested array has an inhomogeneous shape after 1 dimensions. The detected shape was (4,) + inhomogeneous part.

# %%
import numpy as np

# %%
M=np.array([[5,6,7],[2,4,3],[8,9,10],[10,2,3]])

# %%
array([[5,6,7],
       [2,4,3],
       [8,9,10],
       [10,2,3]])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 array([[5,6,7],
#       2        [2,4,3],
#       3        [8,9,10],
#       4        [10,2,3]])
#
# NameError: name 'array' is not defined

# %%
import pandas as pd

# %% [markdown]
# #### series

# %%
S=pd.Series([5,6,7,9,8,9])

# %%
S
# Out:
# 0    5
# 1    6
# 2    7
# 3    9
# 4    8
# 5    9
# dtype: int64

# %%
#https://mitu.co.in/dataset

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\rajesh'

# %%
import pandas as pd

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13212\773397927.py in ?()
# ----> 1 df1=pd.DataFrame("C:\\Users\\rajesh\\student3.csv")
#
# ~\anaconda3\Lib\site-packages\pandas\core\frame.py in ?(self, data, index, columns, dtype, copy)
#     882                 )
#     883         # For data is scalar
#     884         else:
#     885             if index is None or columns is None:
# --> 886                 raise ValueError("DataFrame constructor not properly called!")
#     887
#     888             index = ensure_index(index)
#     889             columns = ensure_index(columns)
#
# ValueError: DataFrame constructor not properly called!

# %%
pwd
# Out:
# 'C:\\Users\\rajesh'

# %%
ls
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is 985B-2269
#
#  Directory of C:\Users\rajesh
#
# 08/16/2024  03:15 PM    <DIR>          .
# 08/16/2024  03:15 PM    <DIR>          ..
# 08/12/2024  02:20 PM    <DIR>          .ai-navigator
# 08/12/2024  10:01 AM    <DIR>          .anaconda
# 08/16/2024  03:17 PM    <DIR>          .conda
# 08/12/2024  02:17 PM                42 .condarc
# 08/12/2024  10:00 AM    <DIR>          .continuum
# 08/23/2023  09:29 AM    <DIR>          .docker
# 08/23/2023  09:22 AM    <DIR>          .eclipse
# 08/16/2024  03:14 PM    <DIR>          .ipynb_checkpoints
# 08/13/2024  02:09 PM    <DIR>          .ipython
# 08/13/2024  02:09 PM    <DIR>          .jupyter
# 08/23/2023  09:24 AM    <DIR>          .p2
# 08/24/2023  09:11 AM    <DIR>          .vscode
# 08/23/2023  12:06 PM    <DIR>          3D Objects
# 08/12/2024  03:07 PM    <DIR>          anaconda3
# 08/23/2023  12:06 PM    <DIR>          Contacts
# ...

# %%
df=pd.read_csv('student.csv')

# %%
df
# Out:
#    roll     name class  marks  age
# 0     1     anil    TE  56.77   22
# 1     2     amit    TE  59.77   21
# 2     3   aniket    BE  76.88   19
# 3     4  ajinkya    TE  69.66   20
# 4     5     asha    TE  63.28   20
# 5     6   ayesha    BE  49.55   20
# 6     7     amar    BE  65.34   19
# 7     8    amita    BE  68.33   23
# 8     9     amol    TE  56.75   20
# 9    10    anmol    BE  78.66   21

# %%
df1=pd.read_csv('student1.csv', names=['A','B','C','D','E'])

# %%
df1
# Out:
#     A        B   C      D   E
# 0   1     anil  TE  56.77  22
# 1   2     amit  TE  59.77  21
# 2   3   aniket  BE  76.88  19
# 3   4  ajinkya  TE  69.66  20
# 4   5     asha  TE  63.28  20
# 5   6   ayesha  BE  49.55  20
# 6   7     amar  BE  65.34  19
# 7   8    amita  BE  68.33  23
# 8   9     amol  TE  56.75  20
# 9  10    anmol  BE  78.66  21

# %%
df.columns()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 df.columns()
#
# TypeError: 'Index' object is not callable

# %%
df=df.columns()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 df=df.columns()
#
# TypeError: 'Index' object is not callable

# %%
df3=pd.read_csv('student3.tsv')

# %%
df3
# Out:
#   roll\tname\tclass\tmarks\tage
# 0        1\tanil\tTE\t56.77\t22
# 1        2\tamit\tTE\t59.77\t21
# 2      3\taniket\tBE\t76.88\t19
# 3     4\tajinkya\tTE\t69.66\t20
# 4        5\tasha\tTE\t63.28\t20
# 5      6\tayesha\tBE\t49.55\t20
# 6        7\tamar\tBE\t65.34\t19
# 7       8\tamita\tBE\t68.33\t23
# 8        9\tamol\tTE\t56.75\t20
# 9      10\tanmol\tBE\t78.66\t21

# %%
df3=pd.read_csv('student3.tsv', sep='\t')

# %% [markdown]
# ###

# %%
df3
# Out:
#    roll     name class  marks  age
# 0     1     anil    TE  56.77   22
# 1     2     amit    TE  59.77   21
# 2     3   aniket    BE  76.88   19
# 3     4  ajinkya    TE  69.66   20
# 4     5     asha    TE  63.28   20
# 5     6   ayesha    BE  49.55   20
# 6     7     amar    BE  65.34   19
# 7     8    amita    BE  68.33   23
# 8     9     amol    TE  56.75   20
# 9    10    anmol    BE  78.66   21

# %%
df
# Out:
#    roll     name class  marks  age
# 0     1     anil    TE  56.77   22
# 1     2     amit    TE  59.77   21
# 2     3   aniket    BE  76.88   19
# 3     4  ajinkya    TE  69.66   20
# 4     5     asha    TE  63.28   20
# 5     6   ayesha    BE  49.55   20
# 6     7     amar    BE  65.34   19
# 7     8    amita    BE  68.33   23
# 8     9     amol    TE  56.75   20
# 9    10    anmol    BE  78.66   21

# %%
df.shape
# Out:
# (10, 5)

# %%
df.columns
# Out:
# Index(['roll', 'name', 'class', 'marks', 'age'], dtype='object')

# %%
df3.columns=['roll', 'full_name', 'class', 'marks', 'age']

# %%
df3
# Out:
#    roll full_name class  marks  age
# 0     1      anil    TE  56.77   22
# 1     2      amit    TE  59.77   21
# 2     3    aniket    BE  76.88   19
# 3     4   ajinkya    TE  69.66   20
# 4     5      asha    TE  63.28   20
# 5     6    ayesha    BE  49.55   20
# 6     7      amar    BE  65.34   19
# 7     8     amita    BE  68.33   23
# 8     9      amol    TE  56.75   20
# 9    10     anmol    BE  78.66   21

# %%
df.head()
# Out:
#    roll     name class  marks  age
# 0     1     anil    TE  56.77   22
# 1     2     amit    TE  59.77   21
# 2     3   aniket    BE  76.88   19
# 3     4  ajinkya    TE  69.66   20
# 4     5     asha    TE  63.28   20

# %%
df.tail()
# Out:
#    roll    name class  marks  age
# 5     6  ayesha    BE  49.55   20
# 6     7    amar    BE  65.34   19
# 7     8   amita    BE  68.33   23
# 8     9    amol    TE  56.75   20
# 9    10   anmol    BE  78.66   21

# %%
## slicing

# %%
df.iloc[2:8,1:4] ##rows 2-7 and columns 1-3
# Out:
#       name class  marks
# 2   aniket    BE  76.88
# 3  ajinkya    TE  69.66
# 4     asha    TE  63.28
# 5   ayesha    BE  49.55
# 6     amar    BE  65.34
# 7    amita    BE  68.33

# %%
df.iloc[[6,8,2],:4]
# Out:
#    roll    name class  marks
# 6     7    amar    BE  65.34
# 8     9    amol    TE  56.75
# 2     3  aniket    BE  76.88

# %%
df.loc[:,'name'] ## column name location
# Out:
# 0       anil
# 1       amit
# 2     aniket
# 3    ajinkya
# 4       asha
# 5     ayesha
# 6       amar
# 7      amita
# 8       amol
# 9      anmol
# Name: name, dtype: object

# %%
df.loc[:,['name','marks']]
# Out:
#       name  marks
# 0     anil  56.77
# 1     amit  59.77
# 2   aniket  76.88
# 3  ajinkya  69.66
# 4     asha  63.28
# 5   ayesha  49.55
# 6     amar  65.34
# 7    amita  68.33
# 8     amol  56.75
# 9    anmol  78.66

# %%
df['name']
# Out:
# 0       anil
# 1       amit
# 2     aniket
# 3    ajinkya
# 4       asha
# 5     ayesha
# 6       amar
# 7      amita
# 8       amol
# 9      anmol
# Name: name, dtype: object

# %%
df[['name','age']]
# Out:
#       name  age
# 0     anil   22
# 1     amit   21
# 2   aniket   19
# 3  ajinkya   20
# 4     asha   20
# 5   ayesha   20
# 6     amar   19
# 7    amita   23
# 8     amol   20
# 9    anmol   21

# %%
df.name
# Out:
# 0       anil
# 1       amit
# 2     aniket
# 3    ajinkya
# 4       asha
# 5     ayesha
# 6       amar
# 7      amita
# 8       amol
# 9      anmol
# Name: name, dtype: object

# %%
df.iloc[2,4]
# Out:
# 19

# %%
df.iloc[range(1,11,20),:]
# Out:
#    roll  name class  marks  age
# 1     2  amit    TE  59.77   21

# %%
import numpy as np

# %%
num=[np.random.randint(1,10) for x in range(5)]

# %%
num
# Out:
# [3, 6, 3, 2, 4]

# %%
df.iloc[num,:]
# Out:
#    roll     name class  marks  age
# 3     4  ajinkya    TE  69.66   20
# 6     7     amar    BE  65.34   19
# 3     4  ajinkya    TE  69.66   20
# 2     3   aniket    BE  76.88   19
# 4     5     asha    TE  63.28   20

# %%
df.drop(5)
# Out:
#    roll     name class  marks  age
# 0     1     anil    TE  56.77   22
# 1     2     amit    TE  59.77   21
# 2     3   aniket    BE  76.88   19
# 3     4  ajinkya    TE  69.66   20
# 4     5     asha    TE  63.28   20
# 6     7     amar    BE  65.34   19
# 7     8    amita    BE  68.33   23
# 8     9     amol    TE  56.75   20
# 9    10    anmol    BE  78.66   21

# %%
df.iloc[1,1]=0

# %%
df
# Out:
#    roll     name class  marks  age
# 0     1     anil    TE  56.77   22
# 1     2        0    TE  59.77   21
# 2     3   aniket    BE  76.88   19
# 3     4  ajinkya    TE  69.66   20
# 4     5     asha    TE  63.28   20
# 5     6   ayesha    BE  49.55   20
# 6     7     amar    BE  65.34   19
# 7     8    amita    BE  68.33   23
# 8     9     amol    TE  56.75   20
# 9    10    anmol    BE  78.66   21

# %%
df.iloc[1,1]='amit'

# %%
df
# Out:
#    roll     name class  marks  age
# 0     1     anil    TE  56.77   22
# 1     2     amit    TE  59.77   21
# 2     3   aniket    BE  76.88   19
# 3     4  ajinkya    TE  69.66   20
# 4     5     asha    TE  63.28   20
# 5     6   ayesha    BE  49.55   20
# 6     7     amar    BE  65.34   19
# 7     8    amita    BE  68.33   23
# 8     9     amol    TE  56.75   20
# 9    10    anmol    BE  78.66   21

# %%
df3=pd.read_csv('student3.csv')

# %%
df3
# Out:
#     roll     name class  marks    age
# 0      1     anil    TE   56.77  22.0
# 1      2     amit    TE   59.77  21.0
# 2      3   aniket    BE   76.88  19.0
# 3      4  ajinkya    TE   69.66  20.0
# 4      5     asha    TE   63.28   NaN
# 5      6   ayesha    BE     NaN  20.0
# 6      7     amar    BE   65.34  19.0
# 7      8    Amita    be   68.33  23.0
# 8      9     amol    TE   56.75  20.0
# 9      9     amol    TE   56.75  20.0
# 10    10    anmol    BE   78.66   NaN
# 11    11   surbhi    TE     NaN  23.0
# 12    12    Sujay    TE   74.12  22.0
# 13    13  subhash    be   88.45  21.0
# 14    14   sachin   NaN   59.33  21.0
# 15    15  shalini    TE   63.45  20.0

# %%
df3['age'].fillna(20) ##data cleaning
# Out:
# 0     22.0
# 1     21.0
# 2     19.0
# 3     20.0
# 4     20.0
# 5     20.0
# 6     19.0
# 7     23.0
# 8     20.0
# 9     20.0
# 10    20.0
# 11    23.0
# 12    22.0
# 13    21.0
# 14    21.0
# 15    20.0
# Name: age, dtype: float64

# %%
df3['age'].isnull()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4      True
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10     True
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# Name: age, dtype: bool

# %%
df3.drop([4,6,7])
# Out:
#     roll     name class  marks    age
# 0      1     anil    TE   56.77  22.0
# 1      2     amit    TE   59.77  21.0
# 2      3   aniket    BE   76.88  19.0
# 3      4  ajinkya    TE   69.66  20.0
# 5      6   ayesha    BE     NaN  20.0
# 8      9     amol    TE   56.75  20.0
# 9      9     amol    TE   56.75  20.0
# 10    10    anmol    BE   78.66   NaN
# 11    11   surbhi    TE     NaN  23.0
# 12    12    Sujay    TE   74.12  22.0
# 13    13  subhash    be   88.45  21.0
# 14    14   sachin   NaN   59.33  21.0
# 15    15  shalini    TE   63.45  20.0

# %%
df3.drop('class',axis=1)
# Out:
#     roll     name  marks    age
# 0      1     anil   56.77  22.0
# 1      2     amit   59.77  21.0
# 2      3   aniket   76.88  19.0
# 3      4  ajinkya   69.66  20.0
# 4      5     asha   63.28   NaN
# 5      6   ayesha     NaN  20.0
# 6      7     amar   65.34  19.0
# 7      8    Amita   68.33  23.0
# 8      9     amol   56.75  20.0
# 9      9     amol   56.75  20.0
# 10    10    anmol   78.66   NaN
# 11    11   surbhi     NaN  23.0
# 12    12    Sujay   74.12  22.0
# 13    13  subhash   88.45  21.0
# 14    14   sachin   59.33  21.0
# 15    15  shalini   63.45  20.0

# %%
df['marks'].mean()
# Out:
# 64.499

# %%
df['marks'].mean(), df['marks'].sum(), df['marks'].std(), df['marks'].min(), df['marks'].max()
# Out:
# (64.499, 644.9899999999999, 9.207178901994535, 49.55, 78.66)

# %% [markdown]
# df.max()

# %%
df.max(numeric_only=True)
# Out:
# roll     10.00
# marks    78.66
# age      23.00
# dtype: float64

# %%
df
# Out:
#    roll     name class  marks  age
# 0     1     anil    TE  56.77   22
# 1     2     amit    TE  59.77   21
# 2     3   aniket    BE  76.88   19
# 3     4  ajinkya    TE  69.66   20
# 4     5     asha    TE  63.28   20
# 5     6   ayesha    BE  49.55   20
# 6     7     amar    BE  65.34   19
# 7     8    amita    BE  68.33   23
# 8     9     amol    TE  56.75   20
# 9    10    anmol    BE  78.66   21

# %%
df.count()
# Out:
# roll     10
# name     10
# class    10
# marks    10
# age      10
# dtype: int64

# %%
df3.dtypes
# Out:
# roll        int64
# name       object
# class      object
# marks     float64
# age       float64
# dtype: object

# %%
df3['age'].astype(int)
# Out:
# ---------------------------------------------------------------------------
# IntCastingNaNError                        Traceback (most recent call last)
# Cell In[90], line 1
# ----> 1 df3['age'].astype(int)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:6643, in NDFrame.astype(self, dtype, copy, errors)
#    6637     results = [
#    6638         ser.astype(dtype, copy=copy, errors=errors) for _, ser in self.items()
#    6639     ]
#    6641 else:
#    6642     # else, only a single dtype is given
# -> 6643     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6644     res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6645     return res.__finalize__(self, method="astype")
#
# File ~\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:430, in BaseBlockManager.astype(self, dtype, copy, errors)
#     427 elif using_copy_on_write():
#     428     copy = False
# --> 430 return self.apply(
#     431     "astype",
# ...

# %% [markdown]
# df3['age']=df3['age'].fillna(2)
# df3['age'].astype(np.int64)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   roll    10 non-null     int64
#  1   name    10 non-null     object
#  2   class   10 non-null     object
#  3   marks   10 non-null     float64
#  4   age     10 non-null     int64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 532.0+ bytes

# %%
df.describe()
# Out:
#            roll      marks        age
# count  10.00000  10.000000  10.000000
# mean    5.50000  64.499000  20.500000
# std     3.02765   9.207179   1.269296
# min     1.00000  49.550000  19.000000
# 25%     3.25000  57.520000  20.000000
# 50%     5.50000  64.310000  20.000000
# 75%     7.75000  69.327500  21.000000
# max    10.00000  78.660000  23.000000

# %% [markdown]
# ### custom columns operations

# %%
df['marks']/10+0.45
# Out:
# 0    6.127
# 1    6.427
# 2    8.138
# 3    7.416
# 4    6.778
# 5    5.405
# 6    6.984
# 7    7.283
# 8    6.125
# 9    8.316
# Name: marks, dtype: float64

# %%
df['marks']=df['marks']+0.5

# %%
df
# Out:
#    roll     name class  marks  age
# 0     1     anil    TE  57.27   22
# 1     2     amit    TE  60.27   21
# 2     3   aniket    BE  77.38   19
# 3     4  ajinkya    TE  70.16   20
# 4     5     asha    TE  63.78   20
# 5     6   ayesha    BE  50.05   20
# 6     7     amar    BE  65.84   19
# 7     8    amita    BE  68.83   23
# 8     9     amol    TE  57.25   20
# 9    10    anmol    BE  79.16   21

# %%
df['cpga']=df['marks']+0.5 ##adds a new column

# %%
df
# Out:
#    roll     name class  marks  age   cpga
# 0     1     anil    TE  57.27   22  57.77
# 1     2     amit    TE  60.27   21  60.77
# 2     3   aniket    BE  77.38   19  77.88
# 3     4  ajinkya    TE  70.16   20  70.66
# 4     5     asha    TE  63.78   20  64.28
# 5     6   ayesha    BE  50.05   20  50.55
# 6     7     amar    BE  65.84   19  66.34
# 7     8    amita    BE  68.83   23  69.33
# 8     9     amol    TE  57.25   20  57.75
# 9    10    anmol    BE  79.16   21  79.66

# %% [markdown]
# #### join, merge, append, concat,connect

# %%
ndf=pd.DataFrame({
    'roll':range(1,11),
    'gender': ['M','M','F','M','M','F','M','M','F','F'],
    'cgpa':df['marks']/10+0.45
})

# %%
ndf
# Out:
#    roll gender   cgpa
# 0     1      M  6.177
# 1     2      M  6.477
# 2     3      F  8.188
# 3     4      M  7.466
# 4     5      M  6.828
# 5     6      F  5.455
# 6     7      M  7.034
# 7     8      M  7.333
# 8     9      F  6.175
# 9    10      F  8.366

# %%
df=pd.read_csv('student.csv')

# %%
df
# Out:
#    roll     name class  marks  age
# 0     1     anil    TE  56.77   22
# 1     2     amit    TE  59.77   21
# 2     3   aniket    BE  76.88   19
# 3     4  ajinkya    TE  69.66   20
# 4     5     asha    TE  63.28   20
# 5     6   ayesha    BE  49.55   20
# 6     7     amar    BE  65.34   19
# 7     8    amita    BE  68.33   23
# 8     9     amol    TE  56.75   20
# 9    10    anmol    BE  78.66   21

# %%
df.columns
# Out:
# Index(['roll', 'name', 'class', 'marks', 'age'], dtype='object')

# %%
ndf.columns
# Out:
# Index(['roll', 'gender', 'cgpa'], dtype='object')

# %%
new_df=df.merge(ndf,on='roll')
new_df
# Out:
#    roll     name class  marks  age gender   cgpa
# 0     1     anil    TE  56.77   22      M  6.177
# 1     2     amit    TE  59.77   21      M  6.477
# 2     3   aniket    BE  76.88   19      F  8.188
# 3     4  ajinkya    TE  69.66   20      M  7.466
# 4     5     asha    TE  63.28   20      M  6.828
# 5     6   ayesha    BE  49.55   20      F  5.455
# 6     7     amar    BE  65.34   19      M  7.034
# 7     8    amita    BE  68.33   23      M  7.333
# 8     9     amol    TE  56.75   20      F  6.175
# 9    10    anmol    BE  78.66   21      F  8.366

# %%
df.merge(ndf)
# Out:
#    roll     name class  marks  age gender   cgpa
# 0     1     anil    TE  56.77   22      M  6.177
# 1     2     amit    TE  59.77   21      M  6.477
# 2     3   aniket    BE  76.88   19      F  8.188
# 3     4  ajinkya    TE  69.66   20      M  7.466
# 4     5     asha    TE  63.28   20      M  6.828
# 5     6   ayesha    BE  49.55   20      F  5.455
# 6     7     amar    BE  65.34   19      M  7.034
# 7     8    amita    BE  68.33   23      M  7.333
# 8     9     amol    TE  56.75   20      F  6.175
# 9    10    anmol    BE  78.66   21      F  8.366

# %%
df1=pd.read_csv('student5.csv')
df1
# Out:
#    roll     name class  marks  age
# 0     1   surbhi    TE  67.44   23
# 1     2    sujay    TE  74.12   22
# 2     3  subhash    BE  82.44   21
# 3     4   sachin    TE  59.33   21
# 4     5  shalini    TE  63.45   20

# %%
pd.concat([df,df1])
# Out:
#    roll     name class  marks  age
# 0     1     anil    TE  56.77   22
# 1     2     amit    TE  59.77   21
# 2     3   aniket    BE  76.88   19
# 3     4  ajinkya    TE  69.66   20
# 4     5     asha    TE  63.28   20
# 5     6   ayesha    BE  49.55   20
# 6     7     amar    BE  65.34   19
# 7     8    amita    BE  68.33   23
# 8     9     amol    TE  56.75   20
# 9    10    anmol    BE  78.66   21
# 0     1   surbhi    TE  67.44   23
# 1     2    sujay    TE  74.12   22
# 2     3  subhash    BE  82.44   21
# 3     4   sachin    TE  59.33   21
# 4     5  shalini    TE  63.45   20

# %%
df2=pd.concat([df,df1],ignore_index=True)
df2
# Out:
#     roll     name class  marks  age
# 0      1     anil    TE  56.77   22
# 1      2     amit    TE  59.77   21
# 2      3   aniket    BE  76.88   19
# 3      4  ajinkya    TE  69.66   20
# 4      5     asha    TE  63.28   20
# 5      6   ayesha    BE  49.55   20
# 6      7     amar    BE  65.34   19
# 7      8    amita    BE  68.33   23
# 8      9     amol    TE  56.75   20
# 9     10    anmol    BE  78.66   21
# 10     1   surbhi    TE  67.44   23
# 11     2    sujay    TE  74.12   22
# 12     3  subhash    BE  82.44   21
# 13     4   sachin    TE  59.33   21
# 14     5  shalini    TE  63.45   20

# %% [markdown]
# #### Boolean filtering

# %%
df['marks']>60
# Out:
# 0    False
# 1    False
# 2     True
# 3     True
# 4     True
# 5    False
# 6     True
# 7     True
# 8    False
# 9     True
# Name: marks, dtype: bool

# %%
mask=df['marks']>60

# %%
df[mask]
# Out:
#    roll     name class  marks  age
# 2     3   aniket    BE  76.88   19
# 3     4  ajinkya    TE  69.66   20
# 4     5     asha    TE  63.28   20
# 6     7     amar    BE  65.34   19
# 7     8    amita    BE  68.33   23
# 9    10    anmol    BE  78.66   21

# %%
df[df['marks']>60]
# Out:
#    roll     name class  marks  age
# 2     3   aniket    BE  76.88   19
# 3     4  ajinkya    TE  69.66   20
# 4     5     asha    TE  63.28   20
# 6     7     amar    BE  65.34   19
# 7     8    amita    BE  68.33   23
# 9    10    anmol    BE  78.66   21

# %%
x=df[(df['marks']>60) & (df['class']=='BE')]
x
# Out:
#    roll    name class  marks  age
# 2     3  aniket    BE  76.88   19
# 6     7    amar    BE  65.34   19
# 7     8   amita    BE  68.33   23
# 9    10   anmol    BE  78.66   21

# %%
x=df[(df['marks']>60) & (df['class']!='BE')]
x
# Out:
#    roll     name class  marks  age
# 3     4  ajinkya    TE  69.66   20
# 4     5     asha    TE  63.28   20

# %%
x.to_csv('output.csv',index=False)

# %% [markdown]
# ### string functions

# %%
name='CDAC'

# %%
name.lower()
# Out:
# 'cdac'

# %%
df['name'].str.upper()
# Out:
# 0       ANIL
# 1       AMIT
# 2     ANIKET
# 3    AJINKYA
# 4       ASHA
# 5     AYESHA
# 6       AMAR
# 7      AMITA
# 8       AMOL
# 9      ANMOL
# Name: name, dtype: object

# %%
df['name'].str.replace('i','ee')
# Out:
# 0       aneel
# 1       ameet
# 2     aneeket
# 3    ajeenkya
# 4        asha
# 5      ayesha
# 6        amar
# 7      ameeta
# 8        amol
# 9       anmol
# Name: name, dtype: object

# %% [markdown]
# #### grouping and aggregation

# %%
df
# Out:
#    roll     name class  marks  age
# 0     1     anil    TE  56.77   22
# 1     2     amit    TE  59.77   21
# 2     3   aniket    BE  76.88   19
# 3     4  ajinkya    TE  69.66   20
# 4     5     asha    TE  63.28   20
# 5     6   ayesha    BE  49.55   20
# 6     7     amar    BE  65.34   19
# 7     8    amita    BE  68.33   23
# 8     9     amol    TE  56.75   20
# 9    10    anmol    BE  78.66   21

# %%
df['class'].value_counts()
# Out:
# class
# TE    5
# BE    5
# Name: count, dtype: int64

# %%
df['age'].value_counts()
# Out:
# age
# 20    4
# 21    2
# 19    2
# 22    1
# 23    1
# Name: count, dtype: int64

# %%
gr=df.groupby('class')
gr.groups
# Out:
# {'BE': [2, 5, 6, 7, 9], 'TE': [0, 1, 3, 4, 8]}

# %%
gr.get_group('TE')
# Out:
#    roll     name class  marks  age
# 0     1     anil    TE  56.77   22
# 1     2     amit    TE  59.77   21
# 3     4  ajinkya    TE  69.66   20
# 4     5     asha    TE  63.28   20
# 8     9     amol    TE  56.75   20

# %%
gr.min()
# Out:
#        roll     name  marks  age
# class
# BE        3     amar  49.55   19
# TE        1  ajinkya  56.75   20
